# %% [markdown]
# # Squat Counter - Sanitized Research Provenance
#
# This notebook is intentionally sanitized for the public repository. Colab execution outputs, personal runtime metadata, private Drive links, local media paths, and generated image payloads were removed.
#
# The production implementation lives in `src/squat_api/mediapipe_runner.py`, `src/squat_api/signal.py`, and `src/squat_api/analyzer.py`. Runtime model and sample video artifacts are mounted from `/models/squat/current` and `/data/squat/samples`, not committed to git.

# %%
MP_LEFT_SHOULDER = 11
MP_LEFT_HIP = 23
MP_LEFT_KNEE = 25
MP_LEFT_ANKLE = 27

SAVGOL_WINDOW = 7
SAVGOL_POLYORDER = 2
PEAK_HEIGHT = 140
PEAK_DISTANCE = 30
PEAK_PROMINENCE = 30
BASELINE_REPS = 3
Z_THRESHOLD = 2.0

# Production code: src/squat_api
